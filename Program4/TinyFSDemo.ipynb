# %%
import os
import sys
from libTinyFS import *
# BLOCKSIZE = 256
# MAGICNUMBER = 0x5A
# fileSystems = []
# dynamicResourceTable = []
# fileDesc = 0

# %%
def main():
    
    print("TEST FOR DISK FUNCTIONS\n")
    filename = "test.txt"
    bnum = 0
    fd = openDisk(filename, 256)
    writeB = str.encode("this is a test to see if this works")
    readB = [None]
    writeBlock(fd, 0, writeB)
    readBlock(fd, bnum, readB)
    print(readB[0])
    print('\n')
    
    
    print("TEST FOR TFS_MKFS\n")
    tfs_mkfs("test.txt", 256)
    f = open('test.txt', 'rb')
    print(f.readlines())
    print('\n')
    
    
    print("TEST FOR TFS_MOUNT\n")
    
    tfs_mount("test.txt")
    print(fileSystems[0].fileName, "Mounted (1 = yes, 0 = no)", fileSystems[0].mounted)
    print('\n')
    
    
    print("TEST FOR TFS_OPEN\n")
    fd = tfs_open("im_a_file")
    f = open('test.txt', 'rb')
    print(f.readlines())
    print(fd)
    print('\n')
    
    
    print("TEST FOR TFS_CLOSE\n")
    print(len(dynamicResourceTable))
    tfs_close(fd)
    print(len(dynamicResourceTable))
    print('\n')
    
    
    print("TEST FOR TFS_WRITE\n")
    fd = tfs_open("im_a_file")
    tfs_write(fd, "hello this is a test", 256)
    f = open('test.txt', 'rb')
    print(f.readlines())
    print('\n')
    
    
    print("TEST FOR TFS_DELETE\n")
    fd = tfs_open("im_a_file")
    tfs_delete(fd)
    f = open('test.txt', 'rb')
    print(f.readlines())
    print('\n')
    
    
    print("TEST FOR TFS_READBYTE\n")
    fd = tfs_open("im_a_file")
    buffer = [None]
    tfs_readByte(fd, buffer)
    print(chr(buffer[0]))
    print('\n')
    
    
    print("TEST FOR TFS_SEEK\n")
    fd = tfs_open("im_a_file")
    buffer = [None]
    tfs_seek(fd, 8)
    tfs_readByte(fd, buffer)
    print(chr(buffer[0]))
    print('\n')
    
    
    
#     print("TEST FOR TFS_STAT\n")
#     fd = tfs_open("im_a_file")
#     tfs_stat(fd)
#     print('\n')
    
    
#     print("TEST FOR TFS_RENAME\n")
#     fd = tfs_open("im_a_file")
#     f = open('test.txt', 'rb')
#     print(f.readlines())
#     tfs_rename("not_a_file", fd)
#     f = open('test.txt', 'rb')
#     print(f.readlines())
#     print('\n')
    
    
    print("TEST FOR TFS_UNMOUNT\n")
    tfs_unmount()
    print(fileSystems[0].fileName, "Mounted (1 = yes, 0 = no)", fileSystems[0].mounted)
    
if __name__ == "__main__":
    main()
# Out:
# TEST FOR DISK FUNCTIONS
#
# b'this is a test to see if this works'
#
#
# TEST FOR TFS_MKFS
#
# [b'\x80\x04\x95E\x00\x00\x00\x00\x00\x00\x00\x8c\tlibTinyFS\x94\x8c\r\n', b'superBlock\x94\x93\x94)\x81\x94}\x94(\x8c\x0bmagicNumber\x94KZ\x8c\r\n', b'freeBlocks\x94]\x94Naub.)\x01\x00\x00\x00\x00\x00\x00\x8c\tlibTinyFS\x94\x8c\x05Inode\x94\x93\x94)\x81\x94}\x94(\x8c\x04name\x94\x8c\x01/\x94\x8c\x05stats\x94\x8c\x02os\x94\x8c\x0bstat_result\x94\x93\x94(M\xb6\x81\x8a\x08J\x05\x03\x00\x00\x00\x84\x00J\x96\xce\xeaNK\x01K\x00K\x00KRJ\x1f\x9f+bJ\x1f\x9f+bJ\xedC(bt\x94}\x94(\x8c\x08st_atime\x94GA\xd8\x8a\xe7\xc7\xc8\xb8T\x8c\x08st_mtime\x94GA\xd8\x8a\xe7\xc7\xc8\xb8T\x8c\x08st_ctime\x94GA\xd8\x8a\x10\xfbs\x8cP\x8c\x0bst_atime_ns\x94\x8a\x08\xe8zSQ`i\xdb\x16\x8c\x0bst_mtime_ns\x94\x8a\x08\xe8zSQ`i\xdb\x16\x8c\x0bst_ctime_ns\x94\x8a\x08\x18\x08-qT\xa1\xda\x16\x8c\x12st_file_attributes\x94K \x8c\x0est_reparse_tag\x94K\x00u\x86\x94R\x94ub.']
#
#
# TEST FOR TFS_MOUNT
#
# test.txt Mounted (1 = yes, 0 = no) 1
#
#
# TEST FOR TFS_OPEN
#
# [b'\x80\x04\x95k\x01\x00\x00\x00\x00\x00\x00\x8c\tlibTinyFS\x94\x8c\r\n', b'superBlock\x94\x93\x94)\x81\x94}\x94(\x8c\x0bmagicNumber\x94KZ\x8c\r\n', b'freeBlocks\x94]\x94h\x00\x8c\x05Inode\x94\x93\x94)\x81\x94}\x94(\x8c\x04name\x94\x8c\tim_a_file\x94\x8c\x05stats\x94\x8c\x02os\x94\x8c\x0bstat_result\x94\x93\x94(M\xb6\x81\x8a\x08J\x05\x03\x00\x00\x00\x84\x00J\x96\xce\xeaNK\x01K\x00K\x00M4\x02J\x1f\x9f+bJ\x1f\x9f+bJ\xedC(bt\x94}\x94(\x8c\x08st_atime\x94GA\xd8\x8a\xe7\xc7\xc9;H\x8c\x08st_mtime\x94GA\xd8\x8a\xe7\xc7\xc8\xc8\xa9\x8c\x08st_ctime\x94GA\xd8\x8a\x10\xfbs\x8cP\x8c\x0bst_atime_ns\x94\x8a\x08dp\xcdQ`i\xdb\x16\x8c\x0bst_mtime_ns\x94\x8a\x08D\xb0bQ`i\xdb\x16\x8c\x0bst_ctime_ns\x94\x8a\x08\x18\x08-qT\xa1\xda\x16\x8c\x12st_file_attributes\x94K \x8c\x0est_reparse_tag\x94K\x00u\x86\x94R\x94ubaub.bt\x94}\x94(\x8c\x08st_atime\x94GA\xd8\x8a\xe7\xc7\xc8\xb8T\x8c\x08st_mtime\x94GA\xd8\x8a\xe7\xc7\xc8\xb8T\x8c\x08st_ctime\x94GA\xd8\x8a\x10\xfbs\x8cP\x8c\x0bst_atime_ns\x94\x8a\x08\xe8zSQ`i\xdb\x16\x8c\x0bst_mtime_ns\x94\x8a\x08\xe8zSQ`i\xdb\x16\x8c\x0bst_ctime_ns\x94\x8a\x08\x18\x08-qT\xa1\xda\x16\x8c\x12st_file_attributes\x94K \x8c\x0est_reparse_tag\x94K\x00u\x86\x94R\x94ub.']
# 32
#
#
# TEST FOR TFS_CLOSE
#
# 27
# 26
#
#
# TEST FOR TFS_WRITE
#
# [b'\x80\x04\x95M\x01\x00\x00\x00\x00\x00\x00]\x94(\x8c\tlibTinyFS\x94\x8c\x05Inode\x94\x93\x94)\x81\x94}\x94(\x8c\x04name\x94\x8c\tim_a_file\x94\x8c\x05stats\x94\x8c\x02os\x94\x8c\x0bstat_result\x94\x93\x94(M\xb6\x81\x8a\x08J\x05\x03\x00\x00\x00\x84\x00J\x96\xce\xeaNK\x01K\x00K\x00M4\x02J\x1f\x9f+bJ\x1f\x9f+bJ\xedC(bt\x94}\x94(\x8c\x08st_atime\x94GA\xd8\x8a\xe7\xc7\xc9\xad\xfe\x8c\x08st_mtime\x94GA\xd8\x8a\xe7\xc7\xc9[\xd3\x8c\x08st_ctime\x94GA\xd8\x8a\x10\xfbs\x8cP\x8c\x0bst_atime_ns\x94\x8a\x08\x9cE8R`i\xdb\x16\x8c\x0bst_mtime_ns\x94\x8a\x08\xfc\xbe\xebQ`i\xdb\x16\x8c\x0bst_ctime_ns\x94\x8a\x08\x18\x08-qT\xa1\xda\x16\x8c\x12st_file_attributes\x94K \x8c\x0est_reparse_tag\x94K\x00u\x86\x94R\x94ubC\x14hello this is a test\x94e.hello this is a test\x94e.\x94R\x94ubaub.bt\x94}\x94(\x8c\x08st_atime\x94GA\xd8\x8a\xe7\xc7\xc8\xb8T\x8c\x08st_mtime\x94GA\xd8\x8a\xe7\xc7\xc8\xb8T\x8c\x08st_ctime\x94GA\xd8\x8a\x10\xfbs\x8cP\x8c\x0bst_atime_ns\x94\x8a\x08\xe8zSQ`i\xdb\x16\x8c\x0bst_mtime_ns\x94\x8a\x08\xe8zSQ`i\xdb\x16\x8c\x0bst_ctime_ns\x94\x8a\x08\x18\x08-qT\xa1\xda\x16\x8c\x12st_file_attributes\x94K \x8c\x0est_reparse_tag\x94K\x00u\x86\x94R\x94ub.']
#
#
# TEST FOR TFS_DELETE
#
# [b'\x80\x04\x95\x1d\x00\x00\x00\x00\x00\x00\x00]\x94(NC\x14hello this is a test\x94e.hello this is a test\x94e.hello this is a test\x94e.hello this is a test\x94e.hello this is a test\x94e.hello this is a test\x94e.\x00\x84\x00J\x96\xce\xeaNK\x01K\x00K\x00M4\x02J\x1f\x9f+bJ\x1f\x9f+bJ\xedC(bt\x94}\x94(\x8c\x08st_atime\x94GA\xd8\x8a\xe7\xc7\xca@\x82\x8c\x08st_mtime\x94GA\xd8\x8a\xe7\xc7\xc9\xce\x15\x8c\x08st_ctime\x94GA\xd8\x8a\x10\xfbs\x8cP\x8c\x0bst_atime_ns\x94\x8a\x08@\xb9\xc0R`i\xdb\x16\x8c\x0bst_mtime_ns\x94\x8a\x08d(VR`i\xdb\x16\x8c\x0bst_ctime_ns\x94\x8a\x08\x18\x08-qT\xa1\xda\x16\x8c\x12st_file_attributes\x94K \x8c\x0est_reparse_tag\x94K\x00u\x86\x94R\x94ubC\x14hello this is a test\x94eub.\xb8T\x8c\x08st_mtime\x94GA\xd8\x8a\xe7\xc7\xc8\xb8T\x8c\x08st_ctime\x94GA\xd8\x8a\x10\xfbs\x8cP\x8c\x0bst_atime_ns\x94\x8a\x08\xe8zSQ`i\xdb\x16\x8c\x0bst_mtime_ns\x94\x8a\x08\xe8zSQ`i\xdb\x16\x8c\x0bst_ctime_ns\x94\x8a\x08\x18\x08-qT\xa1\xda\x16\x8c\x12st_file_attributes\x94K \x8c\x0est_reparse_tag\x94K\x00u\x86\x94R\x94ub.']
#
#
# TEST FOR TFS_READBYTE
#
# h
#
#
# TEST FOR TFS_SEEK
#
# i
#
#
# TEST FOR TFS_UNMOUNT
#
# test.txt Mounted (1 = yes, 0 = no) 0
